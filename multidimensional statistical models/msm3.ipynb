# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import scipy as sp
import scipy.stats
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import seaborn as sb

# %%
df = pd.read_csv('zad3.csv')
df
# Out:
#     1.0  0.76  5.48  -11.6  1.15  4.44
# 0   1.0  0.90  6.13 -12.25  0.36  4.41
# 1   1.0 -0.32  6.10 -14.73 -0.30  4.85
# 2   1.0  0.40  4.09 -13.51  0.38  4.61
# 3   1.0 -1.49  6.14 -11.19  2.14  3.29
# 4   1.0  0.06  5.85 -12.28  2.94  4.60
# 5   1.0  2.21  5.23 -12.80  3.49  6.35
# 6   1.0  0.93  6.28 -15.91  2.26  7.21
# 7   1.0  0.20  6.05 -11.05  4.86  6.31
# 8   1.0 -1.80  3.70 -12.34  3.24  7.93
# 9   1.0  0.26  5.75  -8.70  2.62  5.77
# 10  1.0  0.56  3.99 -11.88  4.95  5.26
# 11  1.0 -0.03  4.64 -14.05  1.81  4.19
# 12  1.0 -0.77  6.46 -13.16  2.49  4.10
# 13  1.0 -0.15  6.52 -12.22  5.44  5.27
# 14  1.0 -0.22  5.18 -10.21  3.16  4.79
# 15  1.0 -0.18  3.43  -8.64  1.45  4.86
# 16  1.0 -1.30  4.09 -15.38  3.12  5.24
# 17  1.0 -0.50  6.56 -10.37  1.82  7.54
# 18  1.0  0.62  3.84 -11.78  3.67  4.84
# 19  1.0  0.38  7.06 -15.62 -0.74  8.11
# 20  1.0 -2.10  3.95 -10.99  2.04  4.74
# 21  1.0 -0.87  5.16 -11.90  4.42  4.63
# 22  1.0  0.57  4.27 -12.73  3.49  5.45
# 23  1.0 -0.81  5.60 -11.31  2.42  4.25
# 24  1.0 -0.22  4.71 -12.62  4.52  3.29
# 25  1.0 -0.28  6.17 -12.80  0.28  5.89
# 26  1.0 -0.17  6.21 -11.87  1.95  2.95
# 27  1.0 -1.31  5.05 -12.32  1.82  4.21
# 28  1.0  1.33  3.91 -13.30  2.07  4.62

# %%
z = np.array
y =
beta = np.dot(np.linalg.inv(np.dot(z.T,z)),np.dot(z.T, y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c0d98d32561b> in <module>
# ----> 1 beta = np.dot(np.linalg.inv(np.dot(z.T,z)),np.dot(z.T, y))
#
# NameError: name 'z' is not defined
